# %%
import datetime as dt
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\TP040804\\FYP_Final\\FeatureSelection'

# %%
import os
os.chdir ('D:\Semester 2 (Final)\FYP (Final)\Dataset\Rossman\Working\FeatureSelection')

# %%
train_store = pd.read_csv("ModellingTrainData2.csv")

# %%
corr = train_store.corr()
#Plot Correlation Matrix using Matplotlib
# %pylab inline
plt.figure(figsize=(10, 10))
plt.imshow(corr, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns);
plt.suptitle('Correlation Matrices', fontsize=15, fontweight='bold')
plt.show()
plt.savefig("CorrelationFeature_Importance.png", bbox_inches="tight")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ###### List of Top 10 Correlation Analysis

# %%
print (corr['Sales'].sort_values(ascending=False)[:11], '\n')
# Out:
# Sales                1.000000
# AvgSalesPerStore     0.705753
# AvgCustStoreMonth    0.555695
# AvgCustStoreYear     0.553658
# AvgCustStore         0.546879
# Promo                0.393477
# DayOfWeek_1          0.157812
# StoreType_b          0.128707
# Assortment_c         0.104706
# PromoInterval_0      0.102961
# Assortment_b         0.057486
# Name: Sales, dtype: float64

# %%
#print ('----------------------')
#print (corr['Sales'].sort_values(ascending=False)[-5:]) #last 5 values`
